# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Import Dataset

# %%
data = pd.read_excel("trupti data science.xlsx",error_bas_lines=False)

# %%
data.head(3)
# Out:
#         BARCODE            BILLNO                             ARTICLE  \
# 0  191665929192  CM/000017/Mar-19  FOOTWEAR-WOMENS FOOTWEAR-SHOES (W)
# 1  191886416327  CM/000013/Mar-19         ACCESSORIES-UNISEX-CAPS (U)
# 2  191888621361  CM/000009/Mar-19     APPARELS-MENS UPPER-T-SHIRT (M)
#
#       DIVISION          SECTION  Gender   DEPARTMENT     Brand    CAT2  \
# 0     Footwear  Womens Footwear   Women    Shoes (W)  SKECHERS   12119
# 1  Accessories           Unisex  Unisex     Caps (U)      NIKE  925293
# 2     Apparels       Mens Upper     Men  T-Shirt (M)      NIKE  AR5003
#
#                          CAT3  ... SALESPERSONNO BILLDATE YYYY-MM Qty  \
# 0                   UNDEFINED  ...         333.0    43552  201903   1
# 1  U NK PRO CAP PATCH TRUCKER  ...           NaN    43552  201903   1
# 2          AS M NSW TEE HBR 3  ...           NaN    43552  201903   1
#
#    Basic Amt  Tax amt  Taxable amt Gross Amt Discount  Net Amt
# ...

# %%
data.isnull().sum()
# Out:
# BARCODE          14681
# BILLNO               9
# ARTICLE              9
# DIVISION             9
# SECTION              9
# Gender               9
# DEPARTMENT           9
# Brand                9
# CAT2                 9
# CAT3              5339
# CAT4              9130
# Article              0
# Size              3015
# CAT6             10096
# RSP                  9
# TAXPERCENT           7
# MRP                  7
# HSNSACCODE           7
# SALESPERSON       8522
# SALESPERSONNO     8522
# BILLDATE             0
# YYYY-MM              0
# Qty                  0
# Basic Amt            0
# Tax amt              0
# Taxable amt          0
# Gross Amt            0
# Discount             0
# Net Amt              0
# Date                 0
# dtype: int64

# %% [markdown]
# Columns Of the Dataset

# %%
data.columns
# Out:
# Index(['BARCODE', 'BILLNO', 'ARTICLE', 'DIVISION', 'SECTION', 'Gender',
#        'DEPARTMENT', 'Brand', 'CAT2', 'CAT3', 'CAT4', 'Article', 'Size',
#        'CAT6', 'RSP', 'TAXPERCENT', 'MRP', 'HSNSACCODE', 'SALESPERSON',
#        'SALESPERSONNO', 'BILLDATE', 'YYYY-MM', 'Qty', 'Basic Amt', 'Tax amt',
#        'Taxable amt', 'Gross Amt', 'Discount', 'Net Amt', 'Date'],
#       dtype='object')

# %% [markdown]
# Mean And Median Of The Distribution of the Dataset

# %%
print("Mean Values in the Distribution")
print("-"*35)
print(data.mean())
print("***********************************")
print("Median Values in the Distribution")
print("-"*35)
print(data.median())
# Out:
# Mean Values in the Distribution
# -----------------------------------
# RSP                2479.398012
# TAXPERCENT           11.200525
# MRP                2476.502032
# SALESPERSONNO      5040.476525
# BILLDATE          43889.853951
# YYYY-MM          201964.574822
# Qty                   0.997051
# Basic Amt          2362.107022
# Tax amt             268.441326
# Taxable amt        1886.985890
# Gross Amt          2228.753153
# Discount             73.430893
# Net Amt            2155.427216
# dtype: float64
# ***********************************
# Median Values in the Distribution
# -----------------------------------
# RSP                1995.00
# TAXPERCENT           12.00
# MRP                1995.00
# SALESPERSONNO       222.00
# BILLDATE          43852.00
# YYYY-MM          202001.00
# Qty                   1.00
# Basic Amt          1995.00
# Tax amt             192.76
# Taxable amt        1513.40
# Gross Amt          1799.00
# Discount              0.00
# ...

# %% [markdown]
# PairPlot

# %%
sns.pairplot(data, hue = 'DIVISION', vars = ['Basic Amt','Tax amt','Taxable amt','Gross Amt','Discount','Net Amt'] )
# Out:
# C:\Users\Trupti\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\Users\Trupti\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\Users\Trupti\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\Users\Trupti\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\Users\Trupti\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# HeatMap

# %%
plt.figure(figsize=(20,10)) 
sns.heatmap(data.corr(), annot=True)

# %% [markdown]
# Line Plot

# %%
plt.style.use('seaborn')
x  = [(i+1) for i in range(14)]
y1 = data['Basic Amt'][1:15]
y2 = data['Tax amt'][1:15]
y3 = data['Gross Amt'][1:15]
y4 = data['Net Amt'][1:15]
plt.plot(x, y1, label="Basic Amt", color = 'B')
plt.plot(x, y2, label="Tax amt", color = 'R')
plt.plot(x, y2, label="Gross Amt", color = 'G')
plt.plot(x, y2, label="Net Amt", color = 'Y')
plt.plot()
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("Line Graph Example")
plt.legend()
plt.show()

# %% [markdown]
# Box Plot:-Taxable Amount

# %%
f,ax=plt.subplots(1,1,figsize=(8,5))
box1=sns.boxplot(x="Taxable amt", data=data, palette="muted",sym='k.')
ax.set_xlabel('Tax Amount')
# Out:
# Text(0.5, 0, 'Tax Amount')

# %% [markdown]
# Box Plot- Tax Amount

# %%
f,ax=plt.subplots(1,1,figsize=(8,5))
box1=sns.boxplot(x="Tax amt", data=data, palette="muted",sym='k.')
ax.set_xlabel('Tax Amount')
# Out:
# Text(0.5, 0, 'Tax Amount')

# %% [markdown]
# Count Plot

# %% [markdown]
# Division

# %%
Division=data['DIVISION'].value_counts(ascending=False).to_frame()
Division
# Out:
#              DIVISION
# Apparels        12479
# Footwear         5727
# Equipments       4376
# Accessories      2161

# %%
fig=plt.figure(figsize=(9,5))
sns.countplot('DIVISION',data=data )
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# SECTION

# %%
Section=data['SECTION'].value_counts(ascending=False).to_frame()
Section
# Out:
#                     SECTION
# Mens Upper             6620
# Mens Footwear          4077
# Mens Lower             3267
# Accessories            2941
# Unisex                 2027
# Womens Upper           1729
# Womens Footwear        1543
# Bags                   1044
# Womens Lower            703
# Sports Accessories      218
# Soccer                  150
# Mens Set                133
# Mens                    128
# Unisex Footwear          62
# Kids Footwear            45
# Girls Upper              21
# Basket Balls             12
# Fitness                  11
# Womens                    6
# Boys Upper                6

# %%
fig=plt.figure(figsize=(45,8))
sns.countplot('SECTION',data=data )
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# Gender

# %%
Gender=data['Gender'].value_counts(ascending=False).to_frame()
Gender
# Out:
#         Gender
# Men      14375
# Unisex    6315
# Women     3981
# Kids        72

# %%
fig=plt.figure(figsize=(8,7))
sns.countplot('Gender',data=data )
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# Department

# %%
Department=data['DEPARTMENT'].value_counts(ascending=False).to_frame()
Department
# Out:
#                            DEPARTMENT
# Shoes (M)                        3235
# Carry Bag                        2941
# T-Shirt (M)                      2862
# Socks (U)                        1516
# Shorts (M)                       1136
# ...                               ...
# Ankle Wrap                          2
# Belts                               2
# Caps (W)                            1
# Slipper (U)                         1
# Sweaters Full Sleeves (W)           1
#
# [86 rows x 1 columns]

# %%
fig=plt.figure(figsize=(15,8))
sns.countplot('DEPARTMENT',data=data )
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# Brand

# %%
Brand =data['Brand'].value_counts(ascending=False).to_frame()
Brand
# Out:
#                 Brand
# NIKE             9605
# LEVIS            3155
# KITCO CF         2941
# PUMA             2540
# SKECHERS         1391
# CELIO            1254
# TRIUMPH           766
# Columbia          630
# Allen Solly       413
# Catwalk           392
# Lee Cooper        271
# Asics             181
# US Polo           180
# Louis Philippe    173
# RIDER             167
# 2GO               157
# TEGO              126
# adidas            113
# CARTAGO            92
# IPANEMA            79
# CLARKS             52
# ADIDAS             48
# One8 Select        12
# ASICS               5

# %%
fig=plt.figure(figsize=(15,7))
sns.countplot('Brand',data=data )
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
